# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaBajpai2711/Gen-AI/blob/main/GenAI_Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
from nltk.corpus import brown

# %%
categories=brown.categories()
print(categories)
print("Total categories:",len(categories))
# Out:
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# Total categories: 15

# %%
brown.words(categories='news')[:20]
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigation',
#  'of',
#  "Atlanta's",
#  'recent',
#  'primary',
#  'election',
#  'produced',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that']

# %%
for category in brown.categories():
  word_count=len(brown.words(categories=category))
  print(f"{category}: {word_count} words")
# Out:
# adventure: 69342 words
# belles_lettres: 173096 words
# editorial: 61604 words
# fiction: 68488 words
# government: 70117 words
# hobbies: 82345 words
# humor: 21695 words
# learned: 181888 words
# lore: 110299 words
# mystery: 57169 words
# news: 100554 words
# religion: 39399 words
# reviews: 40704 words
# romance: 70022 words
# science_fiction: 14470 words
