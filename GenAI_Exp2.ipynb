# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaBajpai2711/Gen-AI/blob/main/GenAI_Exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import json
import string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
text="""
my name is shaurya bajpai and currently i am pursuing bachelors in computer science from the city kanpur
"""
corpus=text.lower()
print(corpus)
# Out:
# my name is shaurya bajpai and currently i am pursuing bachelors in computer science from the city kanpur

# %%
nltk.download('punkt_tab')
tokens=word_tokenize(corpus)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# ['my', 'name', 'is', 'shaurya', 'bajpai', 'and', 'currently', 'i', 'am', 'pursuing', 'bachelors', 'in', 'computer', 'science', 'from', 'the', 'city', 'kanpur']
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
tokens=[word for word in tokens if word not in string.punctuation]
print(tokens)
# Out:
# ['my', 'name', 'is', 'shaurya', 'bajpai', 'and', 'currently', 'i', 'am', 'pursuing', 'bachelors', 'in', 'computer', 'science', 'from', 'the', 'city', 'kanpur']

# %%
stop_words=set(stopwords.words('english'))
clean_tokens=[word for word in tokens if word not in stop_words]
print(clean_tokens)
# Out:
# ['name', 'shaurya', 'bajpai', 'currently', 'pursuing', 'bachelors', 'computer', 'science', 'city', 'kanpur']

# %%
vocabulary=sorted(set(clean_tokens))
print(vocabulary)
# Out:
# ['bachelors', 'bajpai', 'city', 'computer', 'currently', 'kanpur', 'name', 'pursuing', 'science', 'shaurya']

# %%
vocab_dict={"vocabulary":vocabulary}

with open("vocabulary.json","w") as file:
  json.dump(vocab_dict,file,indent=4)

print("Vocabulary saved to vocabulary.json")
# Out:
# Vocabulary saved to vocabulary.json
